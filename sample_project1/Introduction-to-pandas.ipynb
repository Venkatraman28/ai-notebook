# %%
import pandas as pd

# %%
# 2 main datatypes
series = pd.Series(["BMW", "Tesla", "Benz"])

# %%
series
# Out:
# 0      BMW
# 1    Tesla
# 2     Benz
# dtype: object

# %%
# series - 1 dimensional

# %%
colours = pd.Series(["Red", "Blue", "Green"])

# %%
colours
# Out:
# 0      Red
# 1     Blue
# 2    Green
# dtype: object

# %%
# dataframe - 2 dimensional
car_data = pd.DataFrame({"Car make": series, "Colour": colours})
car_data
# Out:
#   Car make Colour
# 0      BMW    Red
# 1    Tesla   Blue
# 2     Benz  Green

# %%
# Import data 
car_sales = pd.read_csv("car-sales.csv")

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %% [markdown]
# ![](pandas-anatomy-of-a-dataframe.png)

# %%
# Exporting a dataframe
car_sales.to_csv("exported-car-sales.csv", index=False)

# %%
exported_csv_file = pd.read_csv("exported-car-sales.csv")
exported_csv_file
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %% [markdown]
# ## Describe data

# %%
# Attribute
car_sales.dtypes

# Functiona
# car_sales.to_csv()
# Out:
# Make             object
# Colour           object
# Odometer (KM)     int64
# Doors             int64
# Price            object
# dtype: object

# %%
car_sales.columns
# Out:
# Index(['Make', 'Colour', 'Odometer (KM)', 'Doors', 'Price'], dtype='object')

# %%
car_columns = car_sales.columns

# %%
car_columns
# Out:
# Index(['Make', 'Colour', 'Odometer (KM)', 'Doors', 'Price'], dtype='object')

# %%
car_sales.index
# Out:
# RangeIndex(start=0, stop=10, step=1)

# %%
car_sales.describe()
# Out:
#        Odometer (KM)      Doors
# count      10.000000  10.000000
# mean    78601.400000   4.000000
# std     61983.471735   0.471405
# min     11179.000000   3.000000
# 25%     35836.250000   4.000000
# 50%     57369.000000   4.000000
# 75%     96384.500000   4.000000
# max    213095.000000   5.000000

# %%
car_sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Make           10 non-null     object
#  1   Colour         10 non-null     object
#  2   Odometer (KM)  10 non-null     int64
#  3   Doors          10 non-null     int64
#  4   Price          10 non-null     object
# dtypes: int64(2), object(3)
# memory usage: 532.0+ bytes

# %%
car_sales.mean(numeric_only=True)
# Out:
# Odometer (KM)    78601.4
# Doors                4.0
# dtype: float64

# %%
car_prices = pd.Series([3000, 1500, 1150500])

# %%
car_prices.mean(numeric_only=True)
# Out:
# np.float64(385000.0)

# %%
car_sales.sum()
# Out:
# Make             ToyotaHondaToyotaBMWNissanToyotaHondaHondaToyo...
# Colour               WhiteRedBlueBlackWhiteGreenBlueBlueWhiteWhite
# Odometer (KM)                                               786014
# Doors                                                           40
# Price            $4,000.00$5,000.00$7,000.00$22,000.00$3,500.00...
# dtype: object

# %%
car_sales["Doors"].sum()
# Out:
# np.int64(40)

# %%
len(car_sales)
# Out:
# 10

# %% [markdown]
# ## Viewing and manipulating data

# %%
# returns top 5 rows
car_sales.head()
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00

# %%
car_sales.tail()
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 5  Toyota  Green          99213      4  $4,500.00
# 6   Honda   Blue          45698      4  $7,500.00
# 7   Honda   Blue          54738      4  $7,000.00
# 8  Toyota  White          60000      4  $6,250.00
# 9  Nissan  White          31600      4  $9,700.00

# %%
# .loc & .iloc
animals = pd.Series(["cat", "dog", "panda", "pig"], index=[0, 3, 5, 1])

# %%
animals
# Out:
# 0      cat
# 3      dog
# 5    panda
# 1      pig
# dtype: object

# %%
animals.loc[3]
# Out:
# 'dog'

# %%
# .loc[index] - loc refers to extract the element at the specified index
car_sales.loc[3]
# Out:
# Make                    BMW
# Colour                Black
# Odometer (KM)         11179
# Doors                     5
# Price            $22,000.00
# Name: 3, dtype: object

# %%
animals.iloc[3]
# Out:
# 'pig'

# %%
# .iloc refere to the position
animals.iloc[3]
# Out:
# 'pig'

# %%
car_sales.iloc[7]
# Out:
# Make                 Honda
# Colour                Blue
# Odometer (KM)        54738
# Doors                    4
# Price            $7,000.00
# Name: 7, dtype: object

# %%
animals.iloc[:3]
# Out:
# 0      cat
# 3      dog
# 5    panda
# dtype: object

# %%
car_sales.iloc[:3]
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 0  Toyota  White         150043      4  $4,000.00
# 1   Honda    Red          87899      4  $5,000.00
# 2  Toyota   Blue          32549      3  $7,000.00

# %%
car_sales.loc[:3]
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00

# %%
car_sales["Colour"]
# Out:
# 0    White
# 1      Red
# 2     Blue
# 3    Black
# 4    White
# 5    Green
# 6     Blue
# 7     Blue
# 8    White
# 9    White
# Name: Colour, dtype: object

# %%
car_sales.Make
# Out:
# 0    Toyota
# 1     Honda
# 2    Toyota
# 3       BMW
# 4    Nissan
# 5    Toyota
# 6     Honda
# 7     Honda
# 8    Toyota
# 9    Nissan
# Name: Make, dtype: object

# %%
# If the column has a space the . notation wont work.

# %%
car_sales[car_sales["Make"] == "Toyota"]
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 0  Toyota  White         150043      4  $4,000.00
# 2  Toyota   Blue          32549      3  $7,000.00
# 5  Toyota  Green          99213      4  $4,500.00
# 8  Toyota  White          60000      4  $6,250.00

# %%
car_sales[car_sales["Odometer (KM)" ] > 10000]
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
pd.crosstab(car_sales["Make"], car_sales["Doors"])
# Out:
# Doors   3  4  5
# Make
# BMW     0  0  1
# Honda   0  3  0
# Nissan  0  2  0
# Toyota  1  3  0

# %%
# Groupby
car_sales.groupby(["Make"]).mean(numeric_only=True)
# Out:
#         Odometer (KM)  Doors
# Make
# BMW      11179.000000   5.00
# Honda    62778.333333   4.00
# Nissan  122347.500000   4.00
# Toyota   85451.250000   3.75

# %%
import pandas as pd
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
car_sales["Doors"].plot
plt.show()

# %%
car_sales["Price"] = car_sales["Price"].str.replace('[\$\,\.]', '', regex=True).astype(int)
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\$'
# <>:1: SyntaxWarning: invalid escape sequence '\$'
# C:\Users\adith\AppData\Local\Temp\ipykernel_22368\908075715.py:1: SyntaxWarning: invalid escape sequence '\$'
#   car_sales["Price"] = car_sales["Price"].str.replace('[\$\,\.]', '', regex=True).astype(int)

# %% [markdown]
# ## Manipulating Data

# %%
car_sales["Make"].str.lower()
# Out:
# 0    toyota
# 1     honda
# 2    toyota
# 3       bmw
# 4    nissan
# 5    toyota
# 6     honda
# 7     honda
# 8    toyota
# 9    nissan
# Name: Make, dtype: object

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price
# 0  Toyota  White         150043      4   400000
# 1   Honda    Red          87899      4   500000
# 2  Toyota   Blue          32549      3   700000
# 3     BMW  Black          11179      5  2200000
# 4  Nissan  White         213095      4   350000
# 5  Toyota  Green          99213      4   450000
# 6   Honda   Blue          45698      4   750000
# 7   Honda   Blue          54738      4   700000
# 8  Toyota  White          60000      4   625000
# 9  Nissan  White          31600      4   970000

# %%
car_sales["Make"] = car_sales["Make"].str.lower()

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price
# 0  toyota  White         150043      4   400000
# 1   honda    Red          87899      4   500000
# 2  toyota   Blue          32549      3   700000
# 3     bmw  Black          11179      5  2200000
# 4  nissan  White         213095      4   350000
# 5  toyota  Green          99213      4   450000
# 6   honda   Blue          45698      4   750000
# 7   honda   Blue          54738      4   700000
# 8  toyota  White          60000      4   625000
# 9  nissan  White          31600      4   970000

# %%
car_sales_missing = pd.read_csv("exported-car-sales.csv")
car_sales_missing
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
car_sales_missing["Odometer (KM)"].fillna(car_sales_missing["Odometer (KM)"].mean(numeric_only=True), inplace=True)

# %%
car_sales_missing
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
car_sales_missing.dropna()
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
car_sales_missing.dropna()
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %% [markdown]
# read_csv
# to_csv
# dropna -> Will drop the row and column which have NaN values

# %%
# Column from series
seats_column = pd.Series([5, 5, 5, 5, 5])

# New column called seats
car_sales["Seats"] = seats_column
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats
# 0  toyota  White         150043      4   400000    5.0
# 1   honda    Red          87899      4   500000    5.0
# 2  toyota   Blue          32549      3   700000    5.0
# 3     bmw  Black          11179      5  2200000    5.0
# 4  nissan  White         213095      4   350000    5.0
# 5  toyota  Green          99213      4   450000    NaN
# 6   honda   Blue          45698      4   750000    NaN
# 7   honda   Blue          54738      4   700000    NaN
# 8  toyota  White          60000      4   625000    NaN
# 9  nissan  White          31600      4   970000    NaN

# %%
car_sales.fillna(5, inplace=True)

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats
# 0  toyota  White         150043      4   400000    5.0
# 1   honda    Red          87899      4   500000    5.0
# 2  toyota   Blue          32549      3   700000    5.0
# 3     bmw  Black          11179      5  2200000    5.0
# 4  nissan  White         213095      4   350000    5.0
# 5  toyota  Green          99213      4   450000    5.0
# 6   honda   Blue          45698      4   750000    5.0
# 7   honda   Blue          54738      4   700000    5.0
# 8  toyota  White          60000      4   625000    5.0
# 9  nissan  White          31600      4   970000    5.0

# %%
# Column from list
fuel_economy = [7.5, 9.2, 4.2, 8.8, 3.6, 1.2, 2.3, 5.3, 2.4, 2.6]
car_sales["Fuel per 100KM"] = fuel_economy

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats  Fuel per 100KM
# 0  toyota  White         150043      4   400000    5.0             7.5
# 1   honda    Red          87899      4   500000    5.0             9.2
# 2  toyota   Blue          32549      3   700000    5.0             4.2
# 3     bmw  Black          11179      5  2200000    5.0             8.8
# 4  nissan  White         213095      4   350000    5.0             3.6
# 5  toyota  Green          99213      4   450000    5.0             1.2
# 6   honda   Blue          45698      4   750000    5.0             2.3
# 7   honda   Blue          54738      4   700000    5.0             5.3
# 8  toyota  White          60000      4   625000    5.0             2.4
# 9  nissan  White          31600      4   970000    5.0             2.6

# %%
# Create a column from another column
car_sales["Total fuel used (L)"] = car_sales["Odometer (KM)"]/100 * car_sales["Fuel per 100KM"]
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats  Fuel per 100KM  \
# 0  toyota  White         150043      4   400000    5.0             7.5
# 1   honda    Red          87899      4   500000    5.0             9.2
# 2  toyota   Blue          32549      3   700000    5.0             4.2
# 3     bmw  Black          11179      5  2200000    5.0             8.8
# 4  nissan  White         213095      4   350000    5.0             3.6
# 5  toyota  Green          99213      4   450000    5.0             1.2
# 6   honda   Blue          45698      4   750000    5.0             2.3
# 7   honda   Blue          54738      4   700000    5.0             5.3
# 8  toyota  White          60000      4   625000    5.0             2.4
# 9  nissan  White          31600      4   970000    5.0             2.6
#
#    Total fuel used  Number of wheels  Total fuel used (L)
# 0        11253.225                 4            11253.225
# 1         8086.708                 4             8086.708
# ...

# %%
# Create a column from single value
car_sales["Number of wheels"] = 4
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats  Fuel per 100KM  \
# 0  toyota  White         150043      4   400000    5.0             7.5
# 1   honda    Red          87899      4   500000    5.0             9.2
# 2  toyota   Blue          32549      3   700000    5.0             4.2
# 3     bmw  Black          11179      5  2200000    5.0             8.8
# 4  nissan  White         213095      4   350000    5.0             3.6
# 5  toyota  Green          99213      4   450000    5.0             1.2
# 6   honda   Blue          45698      4   750000    5.0             2.3
# 7   honda   Blue          54738      4   700000    5.0             5.3
# 8  toyota  White          60000      4   625000    5.0             2.4
# 9  nissan  White          31600      4   970000    5.0             2.6
#
#    Total fuel used  Number of wheels
# 0        11253.225                 4
# 1         8086.708                 4
# 2         1367.058                 4
# ...

# %%
car_sales["Passed road safety"] = True
car_sales.dtypes
# Out:
# Make                    object
# Colour                  object
# Odometer (KM)            int64
# Doors                    int64
# Price                    int64
# Seats                  float64
# Fuel per 100KM         float64
# Total fuel used        float64
# Number of wheels         int64
# Total fuel used (L)    float64
# Passed road safety        bool
# dtype: object

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats  Fuel per 100KM  \
# 0  toyota  White         150043      4   400000    5.0             7.5
# 1   honda    Red          87899      4   500000    5.0             9.2
# 2  toyota   Blue          32549      3   700000    5.0             4.2
# 3     bmw  Black          11179      5  2200000    5.0             8.8
# 4  nissan  White         213095      4   350000    5.0             3.6
# 5  toyota  Green          99213      4   450000    5.0             1.2
# 6   honda   Blue          45698      4   750000    5.0             2.3
# 7   honda   Blue          54738      4   700000    5.0             5.3
# 8  toyota  White          60000      4   625000    5.0             2.4
# 9  nissan  White          31600      4   970000    5.0             2.6
#
#    Total fuel used  Number of wheels  Total fuel used (L)  Passed road safety
# 0        11253.225                 4            11253.225                True
# ...

# %%
# Drop a column
car_sales = car_sales.drop("Total fuel used (L)", axis=1)

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats  Fuel per 100KM  \
# 0  toyota  White         150043      4   400000    5.0             7.5
# 1   honda    Red          87899      4   500000    5.0             9.2
# 2  toyota   Blue          32549      3   700000    5.0             4.2
# 3     bmw  Black          11179      5  2200000    5.0             8.8
# 4  nissan  White         213095      4   350000    5.0             3.6
# 5  toyota  Green          99213      4   450000    5.0             1.2
# 6   honda   Blue          45698      4   750000    5.0             2.3
# 7   honda   Blue          54738      4   700000    5.0             5.3
# 8  toyota  White          60000      4   625000    5.0             2.4
# 9  nissan  White          31600      4   970000    5.0             2.6
#
#    Total fuel used  Number of wheels  Total fuel used (L)  Passed road safety
# 0        11253.225                 4            11253.225                True
# ...

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats  Fuel per 100KM  \
# 0  toyota  White         150043      4   400000    5.0             7.5
# 1   honda    Red          87899      4   500000    5.0             9.2
# 2  toyota   Blue          32549      3   700000    5.0             4.2
# 3     bmw  Black          11179      5  2200000    5.0             8.8
# 4  nissan  White         213095      4   350000    5.0             3.6
# 5  toyota  Green          99213      4   450000    5.0             1.2
# 6   honda   Blue          45698      4   750000    5.0             2.3
# 7   honda   Blue          54738      4   700000    5.0             5.3
# 8  toyota  White          60000      4   625000    5.0             2.4
# 9  nissan  White          31600      4   970000    5.0             2.6
#
#    Total fuel used  Number of wheels  Passed road safety
# 0        11253.225                 4                True
# 1         8086.708                 4                True
# ...

# %%
# frac - shuffle 100 percent of data
car_sales_shuffled = car_sales.sample(frac=1)

# %%
car_sales_shuffled
# Out:
#    level_0  index    Make Colour  Odometer (KM)  Doors    Price  Seats  \
# 0        0      9  nissan  White          31600      4   970000    5.0
# 1        1      5  toyota  Green          99213      4   450000    5.0
# 2        2      7   honda   Blue          54738      4   700000    5.0
# 3        3      0  toyota  White         150043      4   400000    5.0
# 4        4      4  nissan  White         213095      4   350000    5.0
# 5        5      8  toyota  White          60000      4   625000    5.0
# 6        6      3     bmw  Black          11179      5  2200000    5.0
# 7        7      6   honda   Blue          45698      4   750000    5.0
# 8        8      1   honda    Red          87899      4   500000    5.0
# 9        9      2  toyota   Blue          32549      3   700000    5.0
#
#    Fuel per 100KM  Total fuel used  Number of wheels  Passed road safety
# 0             2.6          821.600                 4                True
# ...

# %%
car_sales_shuffled.sample(frac=0.2)
# Out:
#    level_0  index    Make Colour  Odometer (KM)  Doors   Price  Seats  \
# 4        4      4  nissan  White         213095      4  350000    5.0
# 5        5      8  toyota  White          60000      4  625000    5.0
#
#    Fuel per 100KM  Total fuel used  Number of wheels  Passed road safety
# 4             3.6          7671.42                 4                True
# 5             2.4          1440.00                 4                True

# %%
car_sales_shuffled.reset_index(inplace=True)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_22368\2708173002.py in ?()
# ----> 1 car_sales_shuffled.reset_index(inplace=True)
#
# D:\AIML\sample_project1\env\Lib\site-packages\pandas\core\frame.py in ?(self, level, drop, inplace, col_level, col_fill, allow_duplicates, names)
#    6475                     level_values = algorithms.take(
#    6476                         level_values, lab, allow_fill=True, fill_value=lev._na_value
#    6477                     )
#    6478
# -> 6479                 new_obj.insert(
#    6480                     0,
#    6481                     name,
#    6482                     level_values,
#
# D:\AIML\sample_project1\env\Lib\site-packages\pandas\core\frame.py in ?(self, loc, column, value, allow_duplicates)
#    5161                 "'self.flags.allows_duplicate_labels' is False."
#    5162             )
# ...

# %%
car_sales_shuffled
# Out:
#    index    Make Colour  Odometer (KM)  Doors    Price  Seats  Fuel per 100KM  \
# 0      9  nissan  White          31600      4   970000    5.0             2.6
# 1      5  toyota  Green          99213      4   450000    5.0             1.2
# 2      7   honda   Blue          54738      4   700000    5.0             5.3
# 3      0  toyota  White         150043      4   400000    5.0             7.5
# 4      4  nissan  White         213095      4   350000    5.0             3.6
# 5      8  toyota  White          60000      4   625000    5.0             2.4
# 6      3     bmw  Black          11179      5  2200000    5.0             8.8
# 7      6   honda   Blue          45698      4   750000    5.0             2.3
# 8      1   honda    Red          87899      4   500000    5.0             9.2
# 9      2  toyota   Blue          32549      3   700000    5.0             4.2
#
#    Total fuel used  Number of wheels  Passed road safety
# ...

# %%
car_sales_shuffled.reset_index(inplace=True, drop=False)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_22368\2993532951.py in ?()
# ----> 1 car_sales_shuffled.reset_index(inplace=True, drop=False)
#
# D:\AIML\sample_project1\env\Lib\site-packages\pandas\core\frame.py in ?(self, level, drop, inplace, col_level, col_fill, allow_duplicates, names)
#    6475                     level_values = algorithms.take(
#    6476                         level_values, lab, allow_fill=True, fill_value=lev._na_value
#    6477                     )
#    6478
# -> 6479                 new_obj.insert(
#    6480                     0,
#    6481                     name,
#    6482                     level_values,
#
# D:\AIML\sample_project1\env\Lib\site-packages\pandas\core\frame.py in ?(self, loc, column, value, allow_duplicates)
#    5161                 "'self.flags.allows_duplicate_labels' is False."
# ...

# %%
car_sales_shuffled
# Out:
#    level_0  index    Make Colour  Odometer (KM)  Doors    Price  Seats  \
# 0        0      9  nissan  White          31600      4   970000    5.0
# 1        1      5  toyota  Green          99213      4   450000    5.0
# 2        2      7   honda   Blue          54738      4   700000    5.0
# 3        3      0  toyota  White         150043      4   400000    5.0
# 4        4      4  nissan  White         213095      4   350000    5.0
# 5        5      8  toyota  White          60000      4   625000    5.0
# 6        6      3     bmw  Black          11179      5  2200000    5.0
# 7        7      6   honda   Blue          45698      4   750000    5.0
# 8        8      1   honda    Red          87899      4   500000    5.0
# 9        9      2  toyota   Blue          32549      3   700000    5.0
#
#    Fuel per 100KM  Total fuel used  Number of wheels  Passed road safety
# 0             2.6          821.600                 4                True
# ...

# %%
car_sales["Odometer (KM)"] = car_sales["Odometer (KM)"].apply(lambda x : x / 1.6)

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats  Fuel per 100KM  \
# 0  toyota  White      93776.875      4   400000    5.0             7.5
# 1   honda    Red      54936.875      4   500000    5.0             9.2
# 2  toyota   Blue      20343.125      3   700000    5.0             4.2
# 3     bmw  Black       6986.875      5  2200000    5.0             8.8
# 4  nissan  White     133184.375      4   350000    5.0             3.6
# 5  toyota  Green      62008.125      4   450000    5.0             1.2
# 6   honda   Blue      28561.250      4   750000    5.0             2.3
# 7   honda   Blue      34211.250      4   700000    5.0             5.3
# 8  toyota  White      37500.000      4   625000    5.0             2.4
# 9  nissan  White      19750.000      4   970000    5.0             2.6
#
#    Total fuel used  Number of wheels  Passed road safety
# 0        11253.225                 4                True
# 1         8086.708                 4                True
# ...
